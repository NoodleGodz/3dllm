# %%
import json
import ast
import logging
from dataclasses import dataclass, field
from pathlib import Path
from typing import Optional
 
import numpy as np
import pandas as pd
import torch
from scipy.interpolate import RBFInterpolator
from torch.utils.data import Dataset
from BreakingBadDataset import *
# %load_ext autotime
# Out:
# time: 71.1 μs (started: 2026-04-26 15:47:54 +07:00)

# %%
import random

import wandb

# Start a new wandb run to track this script.
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="baybobi4-university-of-science-and-technology-of-hanoi-usth",
    # Set the wandb project where this run will be logged.
    project="my-awesome-project",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.02,
        "architecture": "CNN",
        "dataset": "CIFAR-100",
        "epochs": 10,
    },
)

# Simulate training.
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2**-epoch - random.random() / epoch - offset
    loss = 2**-epoch + random.random() / epoch + offset

    # Log metrics to wandb.
    run.log({"acc": acc, "loss": loss})

# Finish the run and upload any remaining data.
run.finish()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/dangminh/.netrc.
# wandb: Currently logged in as: baybobi4 (baybobi4-university-of-science-and-technology-of-hanoi-usth) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/mnt/shared/dangminh/wandb/run-20260427_020533-iipvlzu9</code>
# Syncing run <strong><a href='https://wandb.ai/baybobi4-university-of-science-and-technology-of-hanoi-usth/my-awesome-project/runs/iipvlzu9' target="_blank">drawn-surf-1</a></strong> to <a href='https://wandb.ai/baybobi4-university-of-science-and-technology-of-hanoi-usth/my-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
ds = BreakingBadDataset(csvfile, dataroot, cfg=cfg)
print(f"\nDataset size : {len(ds)}")
print(f"Classes      : {ds.idx_to_class}")
print(f"Token dim    : {ds.token_dim()}")
# Out:
# Skipped 416 rows with parse_error=TRUE
# Index(['path', 'class', 'caption_idx', 'images_used', 'object_description',
#        'fragment_location', 'fracture_surface', 'missing_piece_size',
#        'break_type', 'fragment_guess', 'confidence', 'caption', 'parse_error',
#        'raw_output', 'elapsed_s'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds = BreakingBadDataset(csvfile, dataroot, cfg=cfg)
#       2 print(f"\nDataset size : {len(ds)}")
#       3 print(f"Classes      : {ds.idx_to_class}")
#
# File /mnt/shared/dangminh/BreakingBadDataset.py:563, in BreakingBadDataset.__init__(self, csv_path, dataset_root, cfg, transform, classes)
#     560     df = df[df["class"].isin(classes)]
#     562 # ── Build class index ─────────────────────────────────────────────────
# ...
